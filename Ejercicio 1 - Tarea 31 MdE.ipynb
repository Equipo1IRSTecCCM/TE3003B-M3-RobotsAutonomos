# %%
import rospy
import numpy as np
from geometry_msgs.msg import Twist
from nav_msgs.msg import Odometry
from sensor_msgs.msg import LaserScan
from smach import State, StateMachine
import smach_ros
from tf.transformations import euler_from_quaternion
from time import sleep

# %%
pos = Twist()
break_v = 0
turn_b = 0
pub = rospy.Publisher('/cmd_vel',Twist,queue_size=10)
rospy.init_node('fsm_ra')
rate = rospy.Rate(10)
puntos = [[0,1],[1,1],[1,0],[0,0]]

# %%
puntos
# Out:
# [[0, 1], [1, 1], [1, 0], [0, 0]]

# %%
def callbackOdom(msg):
    global pos
    pos.linear.x = msg.pose.pose.position.x
    pos.linear.y = msg.pose.pose.position.y
    rot_q = msg.pose.pose.orientation
    (_,_,pos.angular.z) = euler_from_quaternion([rot_q.x, rot_q.y, rot_q.z, rot_q.w])

# %%
def smallest_angle_diff(t,s):
    a = t - s
    a -= 2*np.pi if a > np.pi else -2*np.pi if a < -np.pi else 0
    return a

# %%
def callbackScan(msg):
    global break_v
    global turn_b
    scan = np.array(msg.ranges)
    ang = msg.angle_min - np.pi
    andf = msg.angle_max - np.pi
    inc = msg.angle_increment
    angles = np.arange(ang,andf+inc,inc)
    angles = angles[np.r_[-60:60]]
    scan_f = scan[np.r_[-60:60]]
    angles = angles[~np.isnan(scan_f)]
    scan_f = scan_f[~np.isnan(scan_f)]
    angles = angles[np.isfinite(scan_f)]
    scan_f = scan_f[np.isfinite(scan_f)]
    # Máximo alcanze 0.12 - recomendada 0.15
    if scan_f[scan_f < 0.35].shape[0] > 0:
        break_v = (scan_f.min() - 0.23)/scan_f.min()
        try:
            angle = smallest_angle_diff(angles[scan_f == scan_f.min()],np.pi)
            turn_b = angle + (4*np.pi)/9 if angle < 0 else angle - (4*np.pi)/9
        except:
            turn_b = 0
    else:
        break_v = 1
        turn_b = 0

# %%
class Turn(State):
    def __init__(self):
        State.__init__(self, outcomes=['turnr','fowardr','success'])
    def execute(self, ud):
        global pos
        global pub
        global rate
        global puntos
        if len(puntos) == 0:
            return 'success'
        goal = puntos[0]
        print(goal)
        vel = Twist()
        ang = np.arctan2(goal[1]-pos.linear.y,goal[0]-pos.linear.x)
        vel.angular.z = smallest_angle_diff(ang,pos.angular.z)*2
        vel.angular.z = vel.angular.z if abs(vel.angular.z) <= 2.84 else 2.84*np.sign(vel.angular.z)
        pub.publish(vel)
        rate.sleep()
        if abs(smallest_angle_diff(ang,pos.angular.z)) > 0.01:
            return 'turnr'
        else:
            vel.angular.z = 0
            pub.publish(vel)
            rate.sleep()
            pub.publish(vel)
            rate.sleep()
            return 'fowardr'

# %%
class Foward(State):
    def __init__(self):
        State.__init__(self, outcomes=['turnr','fowardr','success'])
    def execute(self, ud):
        global pos
        global pub
        global rate
        global puntos
        global break_v
        global turn_b
        goal = puntos[0]
        vel = Twist()
        ang = np.arctan2(goal[1]-pos.linear.y,goal[0]-pos.linear.x)
        vel.angular.z = smallest_angle_diff(ang,pos.angular.z)*2 if turn_b == 0 else turn_b*(1-break_v) if break_v >= 0 else 0
        vel.angular.z = vel.angular.z if abs(vel.angular.z) <= 2.84 else 2.84*np.sign(vel.angular.z)
        dis = np.sqrt((pos.linear.x - goal[0])**2 + (pos.linear.y - goal[1])**2)
        vel.linear.x = dis*(break_v)
        vel.linear.x = vel.linear.x if abs(vel.linear.x) <= 0.22 else 0.22*np.sign(vel.linear.x)*abs(break_v)
        pub.publish(vel)
        rate.sleep()
        if dis > 0.01:
            return 'fowardr'
        else:
            puntos.pop(0)
            vel.angular.z = 0
            vel.linear.x = 0
            pub.publish(vel)
            rate.sleep()
            pub.publish(vel)
            rate.sleep()
            if len(puntos) == 0:
                return 'success'
            else:
                return 'turnr'

# %%
def main():
    global pos
    global rate
    
    odom = rospy.Subscriber('/odom',Odometry,callbackOdom)
    scanS = rospy.Subscriber('/scan',LaserScan,callbackScan)
    
    sm = StateMachine(outcomes=['succeeded'])
    sm.userdata.sm_input = 0

    # Open the state machine container. A state machine container holds a number of states.
    with sm:
        
        # Add states to the container, and specify the transitions between states
        # For example, if the outcome of state LOCKED is 'coin', then we transition to state UNLOCKED.
        StateMachine.add('TURN', Turn(), transitions={'turnr':'TURN','fowardr':'FOWARD','success':'succeeded'})
        StateMachine.add('FOWARD', Foward(), transitions={'turnr':'TURN','fowardr':'FOWARD','success':'succeeded'})
    
    # View our state transitions using ROS by creating and starting the instrospection server
    sis = smach_ros.IntrospectionServer('server_name', sm, '/SM_ROOT')
    sis.start()
    
    # Execute the state machine 
    outcome = sm.execute()
    print(outcome)
    # Wait for ctrl-c to stop the application
    if outcome == 'success':
        sis.stop()
    else:
        sleep(1)

# %%
if __name__ == '__main__':
    try:
        main()
    except rospy.ROSInterruptException:
        pass
# Out:
# [INFO] [1681617241.485837, 965.099000]: State machine starting in initial state 'TURN' with userdata:
# 	['sm_input']
# [0, 1]
# [INFO] [1681617241.487425, 965.102000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [0, 1]
# [INFO] [1681617241.596128, 965.202000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [0, 1]
# [INFO] [1681617241.688711, 965.302000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [0, 1]
# [INFO] [1681617241.787866, 965.402000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [0, 1]
# [INFO] [1681617241.888327, 965.502000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [0, 1]
# [INFO] [1681617241.990256, 965.602000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [0, 1]
# [INFO] [1681617242.089576, 965.702000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [0, 1]
# [INFO] [1681617242.189608, 965.802000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [0, 1]
# [INFO] [1681617242.289591, 965.902000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [0, 1]
# [INFO] [1681617242.390415, 966.002000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [0, 1]
# [INFO] [1681617242.490004, 966.102000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [0, 1]
# [INFO] [1681617242.593917, 966.202000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [0, 1]
# [INFO] [1681617242.693726, 966.302000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [0, 1]
# [INFO] [1681617242.793063, 966.402000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [0, 1]
# [INFO] [1681617242.895570, 966.502000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [0, 1]
# [INFO] [1681617242.995187, 966.602000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [0, 1]
# [INFO] [1681617243.093339, 966.702000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [0, 1]
# [INFO] [1681617243.196993, 966.802000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [0, 1]
# [INFO] [1681617243.297035, 966.902000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [0, 1]
# [INFO] [1681617243.396970, 967.002000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [0, 1]
# [INFO] [1681617243.496659, 967.102000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [0, 1]
# [INFO] [1681617243.596588, 967.202000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [0, 1]
# [INFO] [1681617243.697462, 967.302000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [0, 1]
# [INFO] [1681617244.007691, 967.604000]: State machine transitioning 'TURN':'fowardr'-->'FOWARD'
# [INFO] [1681617244.099137, 967.702000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1681617244.196496, 967.802000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1681617244.295714, 967.902000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1681617244.396661, 968.002000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1681617244.497073, 968.102000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1681617244.601779, 968.203000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1681617244.696238, 968.302000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1681617244.795749, 968.402000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1681617244.897086, 968.502000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1681617244.999517, 968.602000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1681617245.097628, 968.702000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1681617245.197746, 968.802000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1681617245.298107, 968.902000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1681617245.397640, 969.002000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1681617245.497952, 969.102000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1681617245.597741, 969.202000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1681617245.697501, 969.302000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1681617245.797350, 969.402000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1681617245.897680, 969.502000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1681617245.998112, 969.602000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1681617246.097908, 969.702000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1681617246.197816, 969.802000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1681617246.298609, 969.902000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1681617246.407131, 970.005000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1681617246.499388, 970.102000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1681617246.602560, 970.205000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1681617246.699763, 970.302000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1681617246.803658, 970.406000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1681617246.899867, 970.502000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1681617247.007342, 970.605000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1681617247.100747, 970.703000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1681617247.199778, 970.802000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1681617247.300496, 970.902000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1681617247.400567, 971.002000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1681617247