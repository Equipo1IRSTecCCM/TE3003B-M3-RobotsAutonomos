# %% [markdown]
# # Tarea 32 - Rodear objetos
# ## Equipo 3

# %% [markdown]
# Primero se importan las librerias necesarias.

# %%
import rospy
import numpy as np
from geometry_msgs.msg import Twist
from nav_msgs.msg import Odometry
from sensor_msgs.msg import LaserScan
from smach import State, StateMachine
import smach_ros
from tf.transformations import euler_from_quaternion
from time import sleep

# %% [markdown]
# Luego se declaran variables globales.

# %%
pos = Twist()
pub = rospy.Publisher('/cmd_vel_rod',Twist,queue_size=10)
rospy.init_node('rodearsm')
rate = rospy.Rate(10)
nfb = False
ilb = False
sl = 0

# %% [markdown]
# Declaramos el callback de Odometría el cual se encarga de dar la posición del robot de acuerdo a sus cálculos de las velocidades hechas en cada motor.

# %%
def callbackOdom(msg):
    global pos
    pos.linear.x = msg.pose.pose.position.x
    pos.linear.y = msg.pose.pose.position.y
    rot_q = msg.pose.pose.orientation
    (_,_,pos.angular.z) = euler_from_quaternion([rot_q.x, rot_q.y, rot_q.z, rot_q.w])

# %% [markdown]
# Esta función sirve para dar la diferencia de ángulo entre dos ángulos en el plano cartesiano.

# %%
def smallest_angle_diff(t,s):
    a = t - s
    a -= 2*np.pi if a > np.pi else -2*np.pi if a < -np.pi else 0
    return a

# %% [markdown]
# Este callback verifica con el LiDAR si tiene obstaculos enfrente y la pared a su izquierda. De los puntos de la pared calcula con regresion el error de ángulo el cual seria la pendiente.

# %%
def callbackScan(msg):
    global nfb
    global ilb
    global sl

    #Import scan
    scan = np.array(msg.ranges)

    #Get angles array
    ang = msg.angle_min - np.pi
    andf = msg.angle_max - np.pi
    inc = msg.angle_increment
    angles = np.arange(ang,andf+inc,inc)

    #Get only front detected points
    anglesf = angles[np.r_[-45:0]]
    scan_f = scan[np.r_[-45:0]]
    anglesf = anglesf[~np.isnan(scan_f)]
    scan_f = scan_f[~np.isnan(scan_f)]
    anglesf = anglesf[np.isfinite(scan_f)]
    scan_f = scan_f[np.isfinite(scan_f)]

    #Get only left detected points
    anglesl = angles[np.r_[55:100]]
    scan_l = scan[np.r_[55:100]]
    anglesl = anglesl[~np.isnan(scan_l)]
    scan_l = scan_l[~np.isnan(scan_l)]
    anglesl = anglesl[np.isfinite(scan_l)]
    scan_l = scan_l[np.isfinite(scan_l)]

    #Get booleans if obstacle in front and wall in its left
    nfb = not scan_f[scan_f < 0.35].shape[0] > 0
    ilb = scan_l[scan_l < 0.35].shape[0] > 0

    #Calculate slope with regression and give it as error
    if scan_l.shape[0] >= 13:
        px = scan_l*np.cos(anglesl)
        py = scan_l*np.sin(anglesl)
        sl = np.sum((px - np.average(px))*(py -np.average(py)))/np.sum((px - np.average(px))**2)

# %% [markdown]
# El estado de giro solo se activa cuando tiene obstaculo enfrente.

# %%
class Turn(State):
    def __init__(self):
        State.__init__(self, outcomes=['a','at','t'])
    def execute(self, ud):
        global pub
        global rate
        global nfb
        global ilb
        vel = Twist()
        vel.angular.z = -np.pi/2
        pub.publish(vel)
        rate.sleep()
        if not nfb:
            return "t"
        elif ilb:
            return "a"
        else:
            return "at"

# %% [markdown]
# El estado de avance y giro se activa cuando no hay obstaculos enfrente ni a su izquierda.

# %%
class AdvanceTurn(State):
    def __init__(self):
        State.__init__(self, outcomes=['a','at','t'])
    def execute(self, ud):
        global pub
        global rate
        global nfb
        global ilb
        vel = Twist()
        vel.angular.z = np.pi/2
        vel.linear.x = 0.11
        pub.publish(vel)
        rate.sleep()
        if not nfb:
            return "t"
        elif ilb:
            return "a"
        else:
            return "at"

# %% [markdown]
# El estado de avance se activa cuando no hay obstáculo en frente y tiene pared a su izquierda. Para estar paralelo a la pared utiliza la pendiente como error donde 0 sería que está totalmente paralelo.

# %%
class Advance(State):
    def __init__(self):
        State.__init__(self, outcomes=['a','at','t'])
    def execute(self, ud):
        global pub
        global rate
        global nfb
        global ilb
        global sl
        vel = Twist()
        vel.angular.z = sl
        vel.angular.z = vel.angular.z if abs(vel.angular.z) <= 2.84 else 2.84*np.sign(vel.angular.z)
        vel.linear.x = 0.11
        pub.publish(vel)
        rate.sleep()
        if not nfb:
            return "t"
        elif ilb:
            return "a"
        else:
            return "at"

# %% [markdown]
# Ésta es la función principal donde se inicializan los nodos suscriptores y la máquina de estados.

# %%
def main():
    global pos
    global rate
    
    odom = rospy.Subscriber('/odom',Odometry,callbackOdom)
    scanS = rospy.Subscriber('/scan',LaserScan,callbackScan)
    
    sm = StateMachine(outcomes=['success','failure'])
    sm.userdata.sm_input = 0

    with sm:

        StateMachine.add('TURN', Turn(), transitions={'t':'TURN','at':'ADVANCETURN','a':'ADVANCE'})
        StateMachine.add('ADVANCE', Advance(), transitions={'t':'TURN','at':'ADVANCETURN','a':'ADVANCE'})
        StateMachine.add('ADVANCETURN', AdvanceTurn(), transitions={'t':'TURN','at':'ADVANCETURN','a':'ADVANCE'})
    
    sis = smach_ros.IntrospectionServer('server_name', sm, '/SM_ROOT')
    sis.start()
    
    outcome = sm.execute()
    
    if outcome == 'success':
        sis.stop()
    else:
        sleep(1)

# %% [markdown]
# Finalmente, para ejecutar el código oficialmente (sin antes haber ya ejecutado las celdas anteriores y lanzado el mundo de turtlebot en Gazebo), se ejecuta la siguiente celda para iniciar con el proceso:

# %%
if __name__ == '__main__':
    try:
        main()
    except rospy.ROSInterruptException:
        pass
# Out:
# [INFO] [1682466728.165987, 672.925000]: State machine starting in initial state 'TURN' with userdata:
# 	['sm_input']
# [INFO] [1682466728.173090, 672.931000]: State machine transitioning 'TURN':'a'-->'ADVANCE'
# [INFO] [1682466728.270607, 673.031000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466728.370058, 673.131000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466728.471454, 673.231000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466728.569251, 673.331000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466728.668475, 673.431000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466728.768313, 673.531000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466728.868638, 673.631000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466728.969233, 673.731000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466729.068533, 673.831000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466729.168521, 673.931000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466729.269717, 674.031000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466729.377413, 674.139000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466729.469405, 674.231000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466729.569518, 674.331000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466729.670365, 674.431000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466729.771320, 674.531000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466729.870699, 674.631000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466729.972759, 674.731000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466730.070578, 674.831000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466730.176404, 674.931000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466730.270556, 675.031000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466730.370776, 675.131000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466730.471016, 675.231000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466730.571236, 675.331000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466730.671633, 675.431000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466730.771513, 675.531000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466730.871853, 675.631000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466730.971598, 675.731000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466731.071952, 675.831000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466731.172303, 675.931000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466731.272106, 676.031000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466731.372009, 676.131000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466731.472512, 676.231000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466731.573879, 676.332000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466731.672894, 676.431000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466731.773519, 676.531000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466731.872979, 676.631000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466731.973038, 676.731000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466732.075046, 676.831000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466732.174258, 676.931000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466732.274430, 677.031000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466732.373699, 677.131000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466732.473929, 677.231000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466732.573981, 677.331000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466732.674195, 677.431000]: State machine transitioning 'ADVANCE':'at'-->'ADVANCETURN'
# [INFO] [1682466732.774922, 677.531000]: State machine transitioning 'ADVANCETURN':'at'-->'ADVANCETURN'
# [INFO] [1682466732.874632, 677.631000]: State machine transitioning 'ADVANCETURN':'a'-->'ADVANCE'
# [INFO] [1682466732.974492, 677.731000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466733.077672, 677.831000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466733.175833, 677.931000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466733.275540, 678.031000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466733.375528, 678.131000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466733.476581, 678.231000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466733.576056, 678.331000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466733.676444, 678.431000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466733.776002, 678.531000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466733.876188, 678.631000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466733.976349, 678.731000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466734.078968, 678.831000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682466734
131000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682467050.965641, 995.231000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682467051.065723, 995.331000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682467051.165922, 995.431000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682467051.266135, 995.531000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682467051.366015, 995.631000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682467051.466271, 995.731000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682467051.566454, 995.831000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682467051.668552, 995.931000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682467051.767119, 996.031000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682467051.867364, 996.131000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682467051.969624, 996.231000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682467052.079401, 996.334000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682467052.172731, 996.431000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682467052.273894, 996.531000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682467052.374758, 996.633000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682467052.472196, 996.731000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682467052.574603, 996.831000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682467052.672175, 996.931000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682467052.770209, 997.031000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682467052.871005, 997.131000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682467052.974336, 997.231000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682467053.078600, 997.334000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682467053.175186, 997.431000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682467053.273528, 997.531000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [INFO] [1682467053.372246, 997.631000]: State machine transitioning 'ADVANCE':'a'-->'ADVANCE'
# [ERROR] [1682467053.390932, 997.649000]: InvalidUserCodeError: Could not execute state 'ADVANCE' of type '<__main__.Advance object at 0x7fad3ed82670>': Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/smach/state_machine.py", line 250, in _update_once
#     outcome = self._current_state.execute(
#   File "/tmp/ipykernel_5765/4184534330.py", line 15, in execute
#     rate.sleep()
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/timer.py", line 103, in sleep
#     sleep(self._remaining(curr_time))
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/timer.py", line 159, in sleep
#     rostime_cond.wait(0.5)
#   File "/usr/lib/python3.8/threading.py", line 306, in wait
#     gotit = waiter.acquire(True, timeout)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /opt/ros/noetic/lib/python3/dist-packages/smach/state_machine.py:250, in StateMachine._update_once(self)
#     249     self._state_transitioning_lock.release()
# --> 250     outcome = self._current_state.execute(
#     251             smach.Remapper(
#     252                 self.userdata,
#     253                 self._current_state.get_registered_input_keys(),
#     254                 self._current_state.get_registered_output_keys(),
#     255                 self._remappings[self._current_label]))
#     256 except smach.InvalidUserCodeError as ex:
#
# Cell In[48], line 15, in Advance.execute(self, ud)
#      14 pub.publish(vel)
# ---> 15 rate.sleep()
#      16 if not nfb:
#
# File /opt/ros/noetic/lib/python3/dist-packages/rospy/timer.py:103, in Rate.sleep(self)
#     102 try:
# --> 103     sleep(self._remaining(curr_time))
#     104 except rospy.exceptions.ROSTimeMovedBackwardsException:
#
# File /opt/ros/noetic/lib/python3/dist-packages/rospy/timer.py:159, in sleep(duration)
#     158     with rostime_cond:
# --> 159         rostime_cond.wait(0.5)
#     161 if rospy.rostime.get_rostime() < initial_rostime:
#
# File /usr/lib/python3.8/threading.py:306, in Condition.wait(self, timeout)
#     305 if timeout > 0:
# --> 306     gotit = waiter.acquire(True, timeout)
#     307 else:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# InvalidUserCodeError                      Traceback (most recent call last)
# Cell In[50], line 3
#       1 if __name__ == '__main__':
#       2     try:
# ----> 3         main()
#       4     except rospy.ROSInterruptException:
#       5         pass
#
# Cell In[49], line 20, in main()
#      17 sis = smach_ros.IntrospectionServer('server_name', sm, '/SM_ROOT')
#      18 sis.start()
# ---> 20 outcome = sm.execute()
#      22 if outcome == 'success':
#      23     sis.stop()
#
# File /opt/ros/noetic/lib/python3/dist-packages/smach/state_machine.py:367, in StateMachine.execute(self, parent_ud)
#     364 # Step through state machine
#     365 while container_outcome is None and self._is_running and not smach.is_shutdown():
#     366     # Update the state machine
# --> 367     container_outcome = self._update_once()
#     369 # Copy output keys
#     370 self._copy_output_keys(self.userdata, parent_ud)
#
# File /opt/ros/noetic/lib/python3/dist-packages/smach/state_machine.py:260, in StateMachine._update_once(self)
#     258     raise ex
#     259 except:
# --> 260     raise smach.InvalidUserCodeError("Could not execute state '%s' of type '%s': " %
#     261                                      (self._current_label, self._current_state)
#     262                                      + traceback.format_exc())
#     263 finally:
#     264     self._state_transitioning_lock.acquire()
#
# InvalidUserCodeError: Could not execute state 'ADVANCE' of type '<__main__.Advance object at 0x7fad3ed82670>': Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/smach/state_machine.py", line 250, in _update_once
#     outcome = self._current_state.execute(
#   File "/tmp/ipykernel_5765/4184534330.py", line 15, in execute
#     rate.sleep()
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/timer.py", line 103, in sleep
#     sleep(self._remaining(curr_time))
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/timer.py", line 159, in sleep
#     rostime_cond.wait(0.5)
#   File "/usr/lib/python3.8/threading.py", line 306, in wait
#     gotit = waiter.acquire(True, timeout)
# KeyboardInterrupt
